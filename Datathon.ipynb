# %% [markdown]
# <a href="https://colab.research.google.com/github/TanmayPK/Datathon/blob/main/Datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - People more likely to die if cardiac arrest in belgium
# - results low despite advacned sys etc
# - how to make survival more likely
# - need to have - 1 - optimal aed placement, 2 - using trained citizens to assist (ideally where the responders are low in availablility - doesn't currently exist in belgium)
#
# - how to implement - find motivation to get people to help, test system with KUL, similar sys already active in other countries. Become a hero. data can save lives
#
# - can source data from other third parties. Dont have to limit to what they give.
#
# - basically goal - save lives
#
# - red cross app - first aid training and app tells you stuff about what to do in emergency
#
# # deadline and timing
#
# - 14h - feb 21 deadline 14h captain uploads in google drive
# - can be in any format
# - don't upload the data
# - 15h45-16h - pick dat voucher team cap (v imp catering (1730 - 1845))
# - 1615h - pitches start
#   - own laptop
#   - no hmdi thunder but regular hdmi available
#   - pitch behind closed doors
#   - time limit 5 mins
#   - jury qa 5 min
#   - graded based on modeling, pitching and visualization
#   - 19h - awards see webpage
#   - 1930-2100h - networking
#   - heating is shut at 5 because money - peak capitalism
#
# # Data
#
# - 3 main parts -
#   - medical transport data
#     - ambulance data
#     - PIT data
#     - Mug data
#   - aed device data
#     - addr, postal, province
#     - type of dev
#     - location of dev
#     - accessibility stuff liike abvailability, hours, private domain
#   - medical intervention data
#     - type of emerg
#     - location of emerg
#     - destination hostpital info
#     - emergency vehicle data
#     - elapsed time between stages
#
# medical transport
# - identifying info has been removed
# - data not clean
# - covers all of belgium
#
# aed
# - missing values
# - info in diff languages
# - inconsistencies
#
# interventions
# - large
# - temporal, geospatial, text
# - not cleaned
# - repeated info
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Tips
#
# - choose correct tool
# - eg packages - Gephi for graph viz, plotly for interactive plot
# - google colab lol
# - app is not req but can make it because apparently we have so much time
# - have fun heh

# %% [markdown]
# ## guide book in every language other than english available later

# %%
import pandas as pd

# %%
file_path = 'aed_locations.parquet.gzip'

df = pd.read_parquet(file_path)

# %%
df.head()
# Out:
#      id  type                address  number  postal_code municipality  \
# 0  13.0  None    Blvd. Fr. Roosevelt    24.0       7060.0     SOIGNIES
# 1  70.0  None        Ch. De Wégimont    76.0       4630.0      Ayeneux
# 2  71.0  None  Place Saint - Lambert     NaN       4020.0        Liège
# 3  72.0  None          Rue du Doyard     NaN       4990.0     Lierneux
# 4  73.0  None     Fond Saint Servais     NaN       4000.0        Liège
#
#   province location public available hours
# 0  Hainaut     None      Y      None  None
# 1    Liège     None   None      None  None
# 2    Liège     None   None      None  None
# 3    Liège     None   None      None  None
# 4    Liège     None   None      None  None
